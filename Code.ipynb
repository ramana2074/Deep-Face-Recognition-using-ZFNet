# %%
import os
from PIL import Image

# Source folder where the images are currently located
source_folder = 'C:\\Contributions\\Programs\\ML_DL\\ZFNET\\archive (15)'

# Target folder where we will organize the images
processed_data_folder = 'C:\\Contributions\\Programs\\ML_DL\\ZFNET\\preprocessed'

# Create the processed folder if it doesn't exist
if not os.path.exists(processed_data_folder):
    os.makedirs(processed_data_folder)

# Process each file in the source folder
for filename in os.listdir(source_folder):
    # Ignore non-image files (e.g., Readme)
    if not filename.startswith("subject") or len(filename.split('.')) < 2:
        continue

    # Extract subject and expression from the filename
    parts = filename.split('.')
    subject = parts[0]  # e.g., "subject01"
    expression = parts[1]  # e.g., "centerlight"

    # Create a folder for each subject if it doesn't exist
    subject_folder = os.path.join(processed_data_folder, subject)
    if not os.path.exists(subject_folder):
        os.makedirs(subject_folder)

    # Define the destination path for the converted image
    dst_path = os.path.join(subject_folder, f"{expression}.jpg")

    # Convert and save the image to JPEG format
    src_path = os.path.join(source_folder, filename)
    try:
        with Image.open(src_path) as img:
            img = img.convert('RGB')  # Convert to RGB format if needed
            img.save(dst_path, 'JPEG')
            print(f"Converted and saved: {dst_path}")  # Print each conversion for confirmation
    except Exception as e:
        print(f"Could not process file {filename}: {e}")
# Out:
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject01\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject01\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject01\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject01\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject01\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject01\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject01\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject01\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject01\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject01\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject01\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject02\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject02\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject02\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject02\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject02\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject02\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject02\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject02\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject02\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject02\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject02\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject03\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject03\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject03\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject03\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject03\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject03\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject03\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject03\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject03\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject03\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject03\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject04\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject04\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject04\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject04\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject04\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject04\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject04\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject04\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject04\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject04\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject04\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject05\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject05\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject05\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject05\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject05\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject05\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject05\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject05\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject05\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject05\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject05\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject06\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject06\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject06\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject06\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject06\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject06\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject06\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject06\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject06\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject06\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject06\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject07\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject07\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject07\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject07\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject07\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject07\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject07\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject07\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject07\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject07\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject07\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject08\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject08\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject08\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject08\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject08\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject08\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject08\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject08\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject08\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject08\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject08\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject09\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject09\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject09\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject09\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject09\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject09\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject09\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject09\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject09\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject09\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject09\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject10\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject10\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject10\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject10\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject10\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject10\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject10\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject10\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject10\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject10\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject10\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject11\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject11\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject11\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject11\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject11\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject11\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject11\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject11\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject11\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject11\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject11\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject12\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject12\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject12\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject12\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject12\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject12\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject12\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject12\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject12\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject12\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject12\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject13\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject13\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject13\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject13\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject13\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject13\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject13\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject13\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject13\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject13\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject13\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject14\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject14\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject14\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject14\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject14\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject14\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject14\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject14\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject14\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject14\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject14\wink.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject15\centerlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject15\glasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject15\happy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject15\leftlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject15\noglasses.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject15\normal.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject15\rightlight.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject15\sad.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject15\sleepy.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject15\surprised.jpg
# Converted and saved: C:\Contributions\Programs\ML_DL\ZFNET\preprocessed\subject15\wink.jpg

# %%
import os
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# ZFNet-Inspired Basic Model
def build_basic_zfnet_model(input_shape, num_classes):
    model = models.Sequential()

    # First Convolutional Block
    model.add(layers.Conv2D(48, (7, 7), strides=(2, 2), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((2, 2)))

    # Second Convolutional Block
    model.add(layers.Conv2D(128, (5, 5), strides=(2, 2), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    # Third Convolutional Block
    model.add(layers.Conv2D(192, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    # Fully Connected Layers
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))  # Simplified dense layer size
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(num_classes, activation='softmax'))

    return model

# Set up data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

input_shape = (224, 224, 3)
train_generator = train_datagen.flow_from_directory(
    'C:\\Contributions\\Programs\\ML_DL\\ZFNET\\preprocessed',
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    'C:\\Contributions\\Programs\\ML_DL\\ZFNET\\preprocessed',
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='validation'
)

# Initialize and compile the ZFNet-inspired model
num_classes = train_generator.num_classes
model = build_basic_zfnet_model(input_shape, num_classes)
model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# Set up callbacks
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)

# Train the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=45,
    callbacks=[lr_scheduler, early_stopping]
)

# Evaluate the model
val_loss, val_accuracy = model.evaluate(val_generator)
print(f"Validation accuracy: {val_accuracy * 100:.2f}%")
# Out:
# Found 135 images belonging to 15 classes.
# Found 30 images belonging to 15 classes.
# Epoch 1/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 0.0470 - loss: 2.7185 - val_accuracy: 0.1333 - val_loss: 2.6904 - learning_rate: 1.0000e-04
# Epoch 2/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.1300 - loss: 2.6833 - val_accuracy: 0.0667 - val_loss: 2.6753 - learning_rate: 1.0000e-04
# Epoch 3/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.1365 - loss: 2.6606 - val_accuracy: 0.3000 - val_loss: 2.6480 - learning_rate: 1.0000e-04
# Epoch 4/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.1670 - loss: 2.6384 - val_accuracy: 0.3333 - val_loss: 2.6129 - learning_rate: 1.0000e-04
# Epoch 5/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.2051 - loss: 2.5864 - val_accuracy: 0.4333 - val_loss: 2.5597 - learning_rate: 1.0000e-04
# Epoch 6/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.2273 - loss: 2.5124 - val_accuracy: 0.3667 - val_loss: 2.4701 - learning_rate: 1.0000e-04
# Epoch 7/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.2429 - loss: 2.3831 - val_accuracy: 0.3333 - val_loss: 2.3490 - learning_rate: 1.0000e-04
# Epoch 8/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.2781 - loss: 2.2489 - val_accuracy: 0.6333 - val_loss: 2.1860 - learning_rate: 1.0000e-04
# Epoch 9/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.3604 - loss: 2.1847 - val_accuracy: 0.4667 - val_loss: 2.0528 - learning_rate: 1.0000e-04
# Epoch 10/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.2516 - loss: 2.1373 - val_accuracy: 0.6333 - val_loss: 1.8841 - learning_rate: 1.0000e-04
# Epoch 11/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.4023 - loss: 1.9194 - val_accuracy: 0.5333 - val_loss: 1.7042 - learning_rate: 1.0000e-04
# Epoch 12/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.5251 - loss: 1.6468 - val_accuracy: 0.6333 - val_loss: 1.5876 - learning_rate: 1.0000e-04
# Epoch 13/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.5426 - loss: 1.4904 - val_accuracy: 0.6667 - val_loss: 1.3914 - learning_rate: 1.0000e-04
# Epoch 14/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.4563 - loss: 1.5578 - val_accuracy: 0.6000 - val_loss: 1.3875 - learning_rate: 1.0000e-04
# Epoch 15/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.5284 - loss: 1.4735 - val_accuracy: 0.7667 - val_loss: 1.2682 - learning_rate: 1.0000e-04
# Epoch 16/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.5665 - loss: 1.2570 - val_accuracy: 0.7667 - val_loss: 1.1109 - learning_rate: 1.0000e-04
# Epoch 17/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.6482 - loss: 1.1682 - val_accuracy: 0.8333 - val_loss: 0.9317 - learning_rate: 1.0000e-04
# Epoch 18/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.6725 - loss: 0.9588 - val_accuracy: 0.8667 - val_loss: 0.8379 - learning_rate: 1.0000e-04
# Epoch 19/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.7705 - loss: 0.8323 - val_accuracy: 0.7667 - val_loss: 0.8158 - learning_rate: 1.0000e-04
# Epoch 20/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.7109 - loss: 0.9075 - val_accuracy: 0.9333 - val_loss: 0.7787 - learning_rate: 1.0000e-04
# Epoch 21/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.6456 - loss: 0.9968 - val_accuracy: 0.8333 - val_loss: 0.6726 - learning_rate: 1.0000e-04
# Epoch 22/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.6342 - loss: 0.9319 - val_accuracy: 0.9667 - val_loss: 0.7027 - learning_rate: 1.0000e-04
# Epoch 23/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.8332 - loss: 0.6786 - val_accuracy: 0.8333 - val_loss: 0.6743 - learning_rate: 1.0000e-04
# Epoch 24/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.7851 - loss: 0.7514 - val_accuracy: 0.9667 - val_loss: 0.4626 - learning_rate: 1.0000e-04
# Epoch 25/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.7516 - loss: 0.6792 - val_accuracy: 0.9000 - val_loss: 0.5513 - learning_rate: 1.0000e-04
# Epoch 26/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.8108 - loss: 0.6099 - val_accuracy: 0.8667 - val_loss: 0.4367 - learning_rate: 1.0000e-04
# Epoch 27/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.8711 - loss: 0.4705 - val_accuracy: 0.9333 - val_loss: 0.4115 - learning_rate: 1.0000e-04
# Epoch 28/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.8094 - loss: 0.5688 - val_accuracy: 0.8667 - val_loss: 0.3986 - learning_rate: 1.0000e-04
# Epoch 29/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.8737 - loss: 0.4372 - val_accuracy: 0.9333 - val_loss: 0.3204 - learning_rate: 1.0000e-04
# Epoch 30/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.8357 - loss: 0.5399 - val_accuracy: 0.9333 - val_loss: 0.4009 - learning_rate: 1.0000e-04
# Epoch 31/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.8448 - loss: 0.5100 - val_accuracy: 0.8667 - val_loss: 0.3958 - learning_rate: 1.0000e-04
# Epoch 32/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.7520 - loss: 0.6202 - val_accuracy: 0.9333 - val_loss: 0.3335 - learning_rate: 1.0000e-04
# Epoch 33/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.8722 - loss: 0.3995 - val_accuracy: 0.9667 - val_loss: 0.2935 - learning_rate: 5.0000e-05
# Epoch 34/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.8758 - loss: 0.3729 - val_accuracy: 0.9667 - val_loss: 0.2815 - learning_rate: 5.0000e-05
# Epoch 35/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.7914 - loss: 0.5193 - val_accuracy: 0.9667 - val_loss: 0.2439 - learning_rate: 5.0000e-05
# Epoch 36/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.9098 - loss: 0.3136 - val_accuracy: 0.9333 - val_loss: 0.2756 - learning_rate: 5.0000e-05
# Epoch 37/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.8819 - loss: 0.3142 - val_accuracy: 0.9667 - val_loss: 0.3042 - learning_rate: 5.0000e-05
# Epoch 38/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.8667 - loss: 0.4363 - val_accuracy: 0.9333 - val_loss: 0.2388 - learning_rate: 5.0000e-05
# Epoch 39/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.9347 - loss: 0.2414 - val_accuracy: 0.9333 - val_loss: 0.2201 - learning_rate: 5.0000e-05
# Epoch 40/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.9276 - loss: 0.2881 - val_accuracy: 0.9667 - val_loss: 0.3266 - learning_rate: 5.0000e-05
# Epoch 41/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.8631 - loss: 0.3856 - val_accuracy: 0.9667 - val_loss: 0.3213 - learning_rate: 5.0000e-05
# Epoch 42/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.8396 - loss: 0.4603 - val_accuracy: 0.9333 - val_loss: 0.2478 - learning_rate: 5.0000e-05
# Epoch 43/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.8444 - loss: 0.3701 - val_accuracy: 0.9667 - val_loss: 0.2303 - learning_rate: 2.5000e-05
# Epoch 44/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.8481 - loss: 0.5088 - val_accuracy: 0.9667 - val_loss: 0.2135 - learning_rate: 2.5000e-05
# Epoch 45/45
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.9176 - loss: 0.2497 - val_accuracy: 0.9667 - val_loss: 0.2289 - learning_rate: 2.5000e-05
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9569 - loss: 0.2394
# Validation accuracy: 96.67%
